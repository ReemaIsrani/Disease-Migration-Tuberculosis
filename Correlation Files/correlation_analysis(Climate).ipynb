# %%
from google.colab import files

# %%
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_excel('merged_correlation.xlsx')
df.head()
# Out:
#                          Location  Year  ...  relative_humidity  average_temperature
# 0  HIMACHALPRADESH_LAHAULANDSPITI  2001  ...          52.993502            10.896160
# 1          HIMACHALPRADESH_KANGRA  2001  ...          32.625065            12.959197
# 2           HIMACHALPRADESH_MANDI  2001  ...          33.534931            13.101363
# 3          HIMACHALPRADESH_SHIMLA  2001  ...          35.653702            13.525538
# 4        HIMACHALPRADESH_HAMIRPUR  2001  ...          29.772431            13.679608
#
# [5 rows x 11 columns]

# %%
df[['Total_cases','New_smear_positive_cases','Year','Quarter','rainfall','relative_humidity','average_temperature','so2','no2','rspm']].dropna()
df.to_csv("without_na.csv")
files.download("without_na.csv")

# %%
df.describe()
# Out:
#                Year       Quarter  ...  relative_humidity  average_temperature
# count  36457.000000  36457.000000  ...       36250.000000         36250.000000
# mean    2010.269386      2.516801  ...          60.158945            24.994465
# std        4.881157      1.117911  ...          20.187203             4.937246
# min     2001.000000      1.000000  ...          18.211706           -10.741935
# 25%     2006.000000      2.000000  ...          42.197622            21.741722
# 50%     2010.000000      3.000000  ...          62.674663            25.265842
# 75%     2015.000000      4.000000  ...          78.410287            28.806779
# max     2018.000000      4.000000  ...          93.732401            35.933925
#
# [8 rows x 10 columns]

# %%
temp_l=df[df['average_temperature']<=15]
temp_m=df[df['average_temperature'].between(16, 28,inclusive=True)]
temp_h=df[df['average_temperature']>28]

# %%
temp_l['str_year']=temp_l['Year'].apply(str)
temp_l['str_year']=temp_l['Year'].apply(str)
temp_l['str_year']
temp_l['str_quarter']=temp_l['Quarter'].apply(str)
temp_l['timeline'] = temp_l['str_year'].str.cat(temp_l['str_quarter'])
df_new = temp_l.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = temp_l.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Temperature Low')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
temp_m['str_year']=temp_m['Year'].apply(str)
temp_m['str_year']=temp_m['Year'].apply(str)
temp_m['str_year']
temp_m['str_quarter']=temp_m['Quarter'].apply(str)
temp_m['timeline'] = temp_m['str_year'].str.cat(temp_m['str_quarter'])
df_new = temp_m.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = temp_m.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Temperature Moderate')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
temp_h['str_year']=temp_h['Year'].apply(str)
temp_h['str_year']=temp_h['Year'].apply(str)
temp_h['str_year']
temp_h['str_quarter']=temp_h['Quarter'].apply(str)
temp_h['timeline'] = temp_h['str_year'].str.cat(temp_h['str_quarter'])
df_new = temp_h.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = temp_h.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Temperature High')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
humidity_l=df[df['relative_humidity']<=50]
humidity_h=df[df['relative_humidity']>50]

# %%
humidity_l['str_year']=humidity_l['Year'].apply(str)
humidity_l['str_year']=humidity_l['Year'].apply(str)
humidity_l['str_year']
humidity_l['str_quarter']=humidity_l['Quarter'].apply(str)
humidity_l['timeline'] = humidity_l['str_year'].str.cat(humidity_l['str_quarter'])
df_new1 = humidity_l.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Relative Humidity Low')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
humidity_h['str_year']=humidity_h['Year'].apply(str)
humidity_h['str_year']=humidity_h['Year'].apply(str)
humidity_h['str_year']
humidity_h['str_quarter']=humidity_h['Quarter'].apply(str)
humidity_h['timeline'] = humidity_h['str_year'].str.cat(humidity_h['str_quarter'])
df_new = humidity_h.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = humidity_h.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Relative Humidity High')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rain_l=df[df['rainfall']<=1000]
rain_m=df[df['rainfall'].between(1001, 3000,inclusive=True)]
rain_h=df[df['rainfall']>3001]

# %%
rain_l['str_year']=rain_l['Year'].apply(str)
rain_l['str_year']=rain_l['Year'].apply(str)
rain_l['str_year']
rain_l['str_quarter']=rain_l['Quarter'].apply(str)
rain_l['timeline'] = rain_l['str_year'].str.cat(rain_l['str_quarter'])
df_new1 = rain_l.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Rainfall Low')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rain_m['str_year']=rain_m['Year'].apply(str)
rain_m['str_year']=rain_m['Year'].apply(str)
rain_m['str_year']
rain_m['str_quarter']=rain_m['Quarter'].apply(str)
rain_m['timeline'] = rain_m['str_year'].str.cat(rain_m['str_quarter'])
df_new = rain_m.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = rain_m.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Rainfall Moderate')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rain_h['str_year']=rain_h['Year'].apply(str)
rain_h['str_year']=rain_h['Year'].apply(str)
rain_h['str_year']
rain_h['str_quarter']=rain_h['Quarter'].apply(str)
rain_h['timeline'] = rain_h['str_year'].str.cat(rain_h['str_quarter'])
df_new = rain_h.groupby('timeline')[['rainfall','Total_cases','New_smear_positive_cases']].sum()
df_new1 = rain_h.groupby('timeline')[['so2','no2','rspm','average_temperature','relative_humidity']].mean()
df_new1
result1 = pd.concat([df_new, df_new1], axis=1, sort=False)
#DF_list = result['Total_cases'].tolist()
DF1_list = result1['Total_cases'].tolist()
#DF2_list = result2['Total_cases'].tolist()
#DF1 = df_main2.T
#DF = df_main.T
#columns = result.index
columns1 = result1.index
#columns2 = result2.index
fig, ax1 = plt.subplots(figsize=(18,7))
plt.title('Rainfall High')
#plt.plot(columns,DF_list,'r-')
plt.plot(columns1,DF1_list,'g-')
#plt.plot(columns2,DF2_list,'b-')
corr = result1.corr()
sn.heatmap(corr,annot=True,square=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
